# %%
import PyPDF2

# %%
pdf = PyPDF2.PdfReader(open(r"C:\Users\xdmar\Downloads\Maris's_Resume.pdf", "rb"))

# %%
pdf.metadata
# Out:
# {'/Title': '',
#  '/Creator': 'wkhtmltopdf 0.12.4',
#  '/Producer': 'Qt 4.8.7',
#  '/CreationDate': "D:20230612165714+02'00'"}

# %%
page = pdf.pages[0]

# %%
text = page.extract_text()
print(text)
# Out:
# Maris Cimermanis
# BI Developer
# I am an ambitious and driven individual, highly
# skilled in using data to facilitate decision-making. I
# have experience in building ETL pipelines,
# developing eﬀective UI solutions and deploying
# them on the web. Right now, I am ﬁnishing my 12
# month Graduate Programme and looking for a
# Data/BI-oriented position
# maris.cimermanis@gmail.com
# +447879875302
# Riga, Latvia
# marischad-app.herokuapp.com/
# linkedin.com/in/maris-
# cimermanis-620b80171
# WORK EXPERIENCE
# Operations Oﬃcer
# Pilgrim’s UK
# 08/2022 - 08/2023
# ,
#
# Cornwall
# Biggest Producer of Higher Welfare Pork in England
# Use of
# SAP ECC
#  Production and AROLINK (Oracle-based SQL system) in
# production planning
# , monitoring, and reporting
# Automation
# of On-site Planning Systems using
# Python, VBA
#  and Bash
# Facilitation of Employee and
# Organisational Change Management
#
# Developing and improving the company's
# Business Intelligence
#  and
#  Data
# Integrity
#  at Pilgrim's UK
# Contact
# :
# -
# Kerry Hoskin
# Line Manager,
# Email- kerry.hoskin@pilgrimsuk.com, ; mobile- +447737219347
# Production Operator
# Estee Lauder Companies
# 10/2020 - 07/2022
# ,
#
# Petersﬁeld
# Technical Work with Groninger Machinery
# Monitoring and improvement of KPI's, Daily use of SAP for ordering
# Work in a fast-paced, eﬃciency-driven environment with thorough attention to
# quality
#
# Contact
# :
# -
# Leoni Charleigh Hart
# Line Manger, Email- leoni.hart@esteelauder.com
# EDUCATION
# MSc in Data Analytics
# University of Portsmouth
# 09/2021 - 09/2022
# ,
#
# Distinction
# Database Management (
# SQL,
# Mongo DB
# ).
# Data Warehousing, Dimensional
# Modeling and
#  ETL
#  processes.
# Big Data Applications (
# Apache
# Spark
# ,
# TensorFlow
# ).
# UI Design
#  And Data Visualisation
# (
# Tableau
# ,
# Plotly Express
# ).
# BSc in Business and Supply Chain Management
# University of Portsmouth
# 09/2018 - 06/2021
# ,
#
# 1st Class Honours
# Project Management
#  for
# Enterprise.
# Enterprise Systems and Processes
# (SAP).
# Business Intelligence (Linear and
# ARIMA modeling
#  in
# R
# ).
# Business Law.
# SKILLS
# Python
# Visual Basic
# SQL
# HTML5 + CSS
# Tableau
# Machine Learning Applications
# Microsoft Excel
# PERSONAL
# PROJECTS
# RigaRealEstate-  real estate prices
# of Riga in diﬀerent areas
# MarisCHAD- a job interview-ready
# chatbot
# BaconMeter - Live Manufacturing
# Performance Tracker
# LANGUAGES
# English
# Native or Bilingual Proﬁciency
# Latvian
# Native or Bilingual Proﬁciency
# Russian
# Native or Bilingual Proﬁciency
# INTERESTS
# Weightlifting
# Reading
# Traveling
# Yoga
# Surﬁng
# Achievements/Tasks
# Achievements/Tasks
# Courses
# Courses

# %%
old_text = "+447879875302"
new_text = "+37128552228"

# %%
text = text.replace(old_text, new_text)
print(text)
# Out:
# Maris Cimermanis
# BI Developer
# I am an ambitious and driven individual, highly
# skilled in using data to facilitate decision-making. I
# have experience in building ETL pipelines,
# developing eﬀective UI solutions and deploying
# them on the web. Right now, I am ﬁnishing my 12
# month Graduate Programme and looking for a
# Data/BI-oriented position
# maris.cimermanis@gmail.com
# +37128552228
# Riga, Latvia
# marischad-app.herokuapp.com/
# linkedin.com/in/maris-
# cimermanis-620b80171
# WORK EXPERIENCE
# Operations Oﬃcer
# Pilgrim’s UK
# 08/2022 - 08/2023
# ,
#
# Cornwall
# Biggest Producer of Higher Welfare Pork in England
# Use of
# SAP ECC
#  Production and AROLINK (Oracle-based SQL system) in
# production planning
# , monitoring, and reporting
# Automation
# of On-site Planning Systems using
# Python, VBA
#  and Bash
# Facilitation of Employee and
# Organisational Change Management
#
# Developing and improving the company's
# Business Intelligence
#  and
#  Data
# Integrity
#  at Pilgrim's UK
# Contact
# :
# -
# Kerry Hoskin
# Line Manager,
# Email- kerry.hoskin@pilgrimsuk.com, ; mobile- +447737219347
# Production Operator
# Estee Lauder Companies
# 10/2020 - 07/2022
# ,
#
# Petersﬁeld
# Technical Work with Groninger Machinery
# Monitoring and improvement of KPI's, Daily use of SAP for ordering
# Work in a fast-paced, eﬃciency-driven environment with thorough attention to
# quality
#
# Contact
# :
# -
# Leoni Charleigh Hart
# Line Manger, Email- leoni.hart@esteelauder.com
# EDUCATION
# MSc in Data Analytics
# University of Portsmouth
# 09/2021 - 09/2022
# ,
#
# Distinction
# Database Management (
# SQL,
# Mongo DB
# ).
# Data Warehousing, Dimensional
# Modeling and
#  ETL
#  processes.
# Big Data Applications (
# Apache
# Spark
# ,
# TensorFlow
# ).
# UI Design
#  And Data Visualisation
# (
# Tableau
# ,
# Plotly Express
# ).
# BSc in Business and Supply Chain Management
# University of Portsmouth
# 09/2018 - 06/2021
# ,
#
# 1st Class Honours
# Project Management
#  for
# Enterprise.
# Enterprise Systems and Processes
# (SAP).
# Business Intelligence (Linear and
# ARIMA modeling
#  in
# R
# ).
# Business Law.
# SKILLS
# Python
# Visual Basic
# SQL
# HTML5 + CSS
# Tableau
# Machine Learning Applications
# Microsoft Excel
# PERSONAL
# PROJECTS
# RigaRealEstate-  real estate prices
# of Riga in diﬀerent areas
# MarisCHAD- a job interview-ready
# chatbot
# BaconMeter - Live Manufacturing
# Performance Tracker
# LANGUAGES
# English
# Native or Bilingual Proﬁciency
# Latvian
# Native or Bilingual Proﬁciency
# Russian
# Native or Bilingual Proﬁciency
# INTERESTS
# Weightlifting
# Reading
# Traveling
# Yoga
# Surﬁng
# Achievements/Tasks
# Achievements/Tasks
# Courses
# Courses

# %%
from fpdf import FPDF
 
# Create PDF object
pdf = FPDF()
 
# Read text file
text2 = text.encode('utf-8').decode('latin-1')
